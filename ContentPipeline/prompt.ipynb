# %% [markdown]
# # S

# %%
    messages = [
        {
            "role": "system",
            "content": (
                "Analyze the user's personality using the Big Five framework based on the user text.\n\n"
                "Later, summarize the user's personality, which can be used as a reference when needed to mimic his/her personality."
                "Input format:\n"
                "{\n"
                "  'user_text': '',\n"
                "}\n"
                "- 'user_text' is the user's social media text.\n"
                "Output the result in this JSON format:\n"
                "{\n"
                "  'dimensions': {\n"
                "    'Openness': {'evidence': ''},\n"
                "    'Conscientiousness': {'evidence': ''},\n"
                "    'Extraversion': {'evidence': ''},\n"
                "    'Agreeableness': {'evidence': ''},\n"
                "    'Neuroticism': {'evidence': ''}\n"
                "  }\n"
                "  'summary': ''\n"
                "}\n"\
                "- 'evidence' is the evidence extracted from the user's text to support the given label.\n"
                "- 'summary' provides an overall synopsis of the user, reflecting all the given personality labels, which can be used as a reference when needed to mimic the user personality.\n\n"
            )
        },
        {
            "role": "user",
            "content": content
        }
    ]

# %%
messages = [
    {
        "role": "system",
        "content": (
            "Analyze the user's personality using the MBTI framework based on the user text.\n\n"
            "Later, summarize the user's personality, which can be used as a reference when needed to mimic his/her personality."
            "Input format:\n"
            "{\n"
            "  'user_text': '',\n"
            "}\n"
            "- 'user_text' is the user's social media text.\n"
            "Output the result in this JSON format:\n"
            "{\n"
            "  'dimensions': {\n"
            "    'Extraversion/Introversion (E/I)': {'input_label': 'E/I', 'evidence': ''},\n"
            "    'Sensing/Intuition (S/N)': {'input_label': 'S/N', 'evidence': ''},\n"
            "    'Thinking/Feeling (T/F)': {'input_label': 'T/F', 'evidence': ''},\n"
            "    'Judging/Perceiving (J/P)': {'input_label': 'J/P', 'evidence': ''}\n"
            "  }\n"
            "  'summary': ''\n"
            "}\n"
            "- 'evidence' is the evidence extracted from the user's text to support the given label.\n"
            "- 'summary' provides an overall synopsis of the user, reflecting all the given personality labels, which can be used as a reference when needed to mimic the user personality.\n\n"
        )
    },
    {
        "role": "user",
        "content": content
    }
]

# %% [markdown]
# # C<sup>R</sup>

# %%
messages = [
    {
        "role": "user",
        "parts": (
            "Analyze the user's personality using the Big 5 framework based on the given text.\n"
            "Output the result in this JSON format:\n"
            "{\n"
            "  'dimensions': {\n"
            "    'Openness': {'evidence': '', 'label': '0/1'},\n"
            "    'Conscientiousness': {'evidence': '', 'label': '0/1'},\n"
            "    'Extraversion': {'evidence': '', 'label': '0/1'},\n"
            "    'Agreeableness': {'evidence': '', 'label': '0/1'},\n"
            "    'Neuroticism': {'evidence': '', 'label': '0/1'}\n"
            "  }\n"
            "}\n\n"
            "For each dimension, provide:\n"
            "- evidence: Analysis of the text reflecting the trait. Give examples (content and/or tone) from the user's message. Avoid using punctuation\n"
            "- label: Provide only a value (0 for low; or 1 for high) to indicate the traits.\n\n"
        )
    }
]

# %%
messages = [
    {
        "role": "system",
        "content": (
            "Analyze the user's personality using the MBTI framework based on given text.\n"
            "Output the result in this JSON format:"
            "{"
            "  'dimensions': {"
            "    'Extraversion/Introversion (E/I)': {'evidence': '', 'type': 'E/I'},"
            "    'Sensing/Intuition (S/N)': {'evidence': '', 'type': 'S/N'},"
            "    'Thinking/Feeling (T/F)': {'evidence': '', 'type': 'T/F'},"
            "    'Judging/Perceiving (J/P)': {'evidence': '', 'type': 'J/P'}"
            "  }"
            "}"
            "For each dimension, provide:\n"
            "- evidence: Analysis of the text reflecting the trait. Give examples (content and/or tone) from the user's message.\n"
            "- type: Infer ONLY one type for each dimension, even if the preference is unclear. Pick ONLY one (1) from the given options.\n\n"
        )
    },
    {
        "role": "user",
        "content": user_text
    }
]

# %% [markdown]
# # C<sup>RT</sup>

# %%
from openai import OpenAI
client = OpenAI(
    api_key="____"
)

def build_single_train(user_text, sample_output):
    messages = [
        {
            "role": "system",
            "content": (
                "Analyze the user's personality using the Big 5 framework based on the given text obtained from social media and the determined personality facets.\n"
                "Input format:\n"
                "{\n"
                "  'user_text': ''\n"
                "  'personality_facets': [...]\n"
                "}\n"
                "- 'user_text': the user social media text.\n"
                "- 'personality_facets': a list of the determined personality facets from the user text\n"
                "Output the result in this JSON format:\n"
                "{\n"
                "  'dimensions': {\n"
                "    'Openness': {'evidence': '', 'label': '0/1'},\n"
                "    'Conscientiousness': {'evidence': '', 'label': '0/1'},\n"
                "    'Extraversion': {'evidence': '', 'label': '0/1'},\n"
                "    'Agreeableness': {'evidence': '', 'label': '0/1'},\n"
                "    'Neuroticism': {'evidence': '', 'label': '0/1'}\n"
                "  }\n"
                "}\n\n"
                "For each dimension, provide:\n"
                "- evidence: Analysis of the text reflecting the trait. Give examples (content and/or tone) from the given user's message or personality facets. Avoid using punctuation\n"
                "- label: Provide only a value (0 for low; or 1 for high) to indicate the traits.\n\n"
            )
        },
        {
            "role": "user",
            "content": user_text
        },
        {
            "role": "assistant",
            "content": sample_output
        }
    ]

    # create json
    json_data = {
        "messages": messages
    }

    return json_data


def build_json(line):
    line["o_evi"]
    json_data = {
        'dimensions' :{
            'openness': {'evidence': str(line["o_evi"].item()), 'label': str(line["O"].item())},
            'conscientiousness': {'evidence': str(line["c_evi"].item()), 'label': str(line["C"].item())},
            'extraversion': {'evidence': str(line["e_evi"].item()), 'label': str(line["E"].item())},
            'agreeableness': {'evidence': str(line["a_evi"].item()), 'label': str(line["A"].item())},
            'neuroticism': {'evidence': str(line["n_evi"].item()), 'label': str(line["N"].item())}
        }
    }

    return json.dumps(json_data)

with open(f"{name}.jsonl", "w") as f:
    for _, line in dataset.iterrows():
        id = line["__index_level_0__"]
        #check if id exist in ans_df
        if id not in ans_df["id"].values:
            print("E=", id)
            continue
        ans = ans_df[ans_df["id"] == id]
        ans_json = build_json(ans)
        train_row = build_single_train(line["text"], ans_json)
        f.write(json.dumps(train_row) + "\n")

# %%
 model = genai.GenerativeModel(
        model_name="tunedModels/increment-baie892th00"
    )

    chat_session = model.start_chat(
        history= [
            {
                "role": "user",
                "parts": (
                    "Analyze the user's personality using the Big 5 framework based on the given text.\n"
                    "Output the result in this JSON format:\n"
                    "{\n"
                    "  'dimensions': {\n"
                    "    'Openness': {'evidence': '', 'label': '0/1'},\n"
                    "    'Conscientiousness': {'evidence': '', 'label': '0/1'},\n"
                    "    'Extraversion': {'evidence': '', 'label': '0/1'},\n"
                    "    'Agreeableness': {'evidence': '', 'label': '0/1'},\n"
                    "    'Neuroticism': {'evidence': '', 'label': '0/1'}\n"
                    "  }\n"
                    "}\n\n"
                    "For each dimension, provide:\n"
                    "- evidence: Analysis of the text reflecting the trait. Give examples (content and/or tone) from the user's message. Avoid using punctuation\n"
                    "- label: Provide only a value (0 for low; or 1 for high) to indicate the traits.\n\n"
     
                )
            }
        ]
    )

# %% [markdown]
# # C<sup>PR</sup>

# %% [markdown]
# messages = [
#     {
#         "role": "system",
#         "content": (
#             "Analyze the user's personality using the Big 5 framework based on the given content summarised from social media and the determined personality facets.\n"
#             "Input format:\n"
#             "{\n"
#             "  'user_content': ''\n"
#             "  'personality_facets': [...]\n"
#             "}\n"
#             "- 'user_content': the summarised user social media content.\n"
#             "- personality_facets: a list of the determined personality facets from the user text\n"
#             "Output the result in this JSON format:\n"
#             "{\n"
#             "  'dimensions': {\n"
#             "    'Openness': {'evidence': '', 'label': '0/1'},\n"
#             "    'Conscientiousness': {'evidence': '', 'label': '0/1'},\n"
#             "    'Extraversion': {'evidence': '', 'label': '0/1'},\n"
#             "    'Agreeableness': {'evidence': '', 'label': '0/1'},\n"
#             "    'Neuroticism': {'evidence': '', 'label': '0/1'}\n"
#             "  }\n"
#             "}\n\n"
#             "For each dimension, provide:\n"
#             "- evidence: Analysis of the text reflecting the trait. Give examples (content and/or tone) from the given user's message or personality facets. Avoid using punctuation\n"
#             "- label: Provide only a value (0 for low; or 1 for high) to indicate the traits.\n\n"
#         )
#     },
#     {
#         "role": "user",
#         "content": user_content
#     }
# ]

# %%
messages = [
    {
        "role": "system",
        "content": (
            "Analyze the user's personality using the MBTI framework based on the user text and the given labels.\n\n"
            "Later, summarize the user's personality, which can be used as a reference when needed to mimic his/her personality."
            "Input format:\n"
            "{\n"
            "  'user_text': '',\n"
            "  'given_labels': {\n"
            "    'Extraversion/Introversion (E/I)': {'evidence': '', 'type': 'E/I'},"
            "    'Sensing/Intuition (S/N)': {'evidence': '', 'type': 'S/N'},"
            "    'Thinking/Feeling (T/F)': {'evidence': '', 'type': 'T/F'},"
            "    'Judging/Perceiving (J/P)': {'evidence': '', 'type': 'J/P'}"
            "  }\n"
            "}\n"
            "- 'user_text' is the user's social media text.\n"
            "- 'given_labels' are the assigned label values (0 for low; 1 for high).\n\n"
            "Output the result in this JSON format:\n"
            "{\n"
            "  'dimensions': {\n"
            "    'Extraversion/Introversion (E/I)': {'input_label': 'E/I', 'evidence': ''},\n"
            "    'Sensing/Intuition (S/N)': {'input_label': 'S/N', 'evidence': ''},\n"
            "    'Thinking/Feeling (T/F)': {'input_label': 'T/F', 'evidence': ''},\n"
            "    'Judging/Perceiving (J/P)': {'input_label': 'J/P', 'evidence': ''}\n"
            "  }\n"
            "  'summary': ''\n"
            "}\n"
            "- 'input_label' is the given MBTI label value.\n"
            "- 'evidence' is the evidence extracted from the user's text to support the given label.\n"
            "- 'summary' provides an overall synopsis of the user, reflecting all the given personality labels, which can be used as a reference when needed to mimic the user personality.\n\n"
        )
    },
    {
        "role": "user",
        "content": content
    }
]

# %% [markdown]
# # P

# %%
response_format ={
    "type": "json_schema",
    "json_schema": {
      "name": "psycho_llm_essays",
      "schema":{
          "$schema": "https://json-schema.org/draft/2020-12/schema",
          "$id": "https://example.com/personality-analysis.schema.json",
          "title": "Personality Analysis",
          "description": "Schema for validating personality analysis output",
          "type": "object",
          "properties": {
            "evidence": {
              "description": "Analysis of the text reflecting the personality facets, including examples from the user's message.",
              "type": "string",
              "additionalProperties" : False
            },
            "facet_list": {
              "description": "A list of identified personality facets.",
              "type": "array",
              "items": {
                "type": "string",
                "enum": [
                  "Absorption",
                  "Abstract thinking",
                  "Achievement-striving",
                  "Aesthetics",
                  "Affability",
                  "Aggression",
                  "Altruism",
                  "Anger",
                  "Anxiety",
                  "Assertive",
                  "Attention-seeking",
                  "Callous",
                  "Courageous",
                  "Critical",
                  "Dependability",
                  "Depression",
                  "Detail-conscious",
                  "Dishonest-Opportunism",
                  "Distractibility",
                  "Eccentricity",
                  "Emotion-based decision-making",
                  "Empathy",
                  "Envy",
                  "Extrospection",
                  "Fair",
                  "Fantasy",
                  "Forgiving",
                  "Grandiosity",
                  "Gratitude",
                  "Harm avoidance",
                  "Hedonism",
                  "Honesty",
                  "Humor",
                  "Imagination",
                  "Impetuous",
                  "Indecisive",
                  "Inferiority",
                  "Insecure attachment",
                  "Intellectual curiosity",
                  "Intolerance",
                  "Introspection",
                  "Leadership",
                  "Manipulative",
                  "Need for cognition",
                  "Need for social acceptance",
                  "Novelty seeking",
                  "Orderly",
                  "Perseverance",
                  "Personal disclosure",
                  "Planful",
                  "Positivity",
                  "Procrastination",
                  "Provocative",
                  "Punitive",
                  "Risk-aversion",
                  "Rude",
                  "Rumination",
                  "Self-control",
                  "Self-efficacy",
                  "Self-reliance",
                  "Sensation seeking",
                  "Sensitivity",
                  "Sensitivity to criticism",
                  "Sociability",
                  "Social boldness",
                  "Social confidence",
                  "Social dependence",
                  "Spirituality",
                  "Stubborn",
                  "Surgency",
                  "Suspicious",
                  "Tolerance for ambiguity",
                  "Traditionalism",
                  "Vengeful",
                  "Vigor",
                  "Warmth",
                  "Worry"
                ],
                "additionalProperties" : False
              },
            }
          },
          "required": ["evidence", "facet_list"],
          "additionalProperties" : False
      },
      "strict": True
    }
}

# %%
messages = [
        {
            "role": "system",
            "content": (
                "Analyze the user's personality facets based on the given text obtained from social media.\n"
                "Input format:\n"
                "{\n"
                "  'user_text': ''\n"
                "}\n"
                "- 'user_text: the social media text.\n"
                "Output the result in this JSON format:\n"
                "{\n"
                "  'evidence': ''\n"
                "  'facet_list': '[...]'\n" 
                "}\n"
                "- 'evidence': Analysis of the text reflecting the personality facets. Give examples (content and/or tone) from the given user's message.\n"
                "- 'facet_list': a list of facets identified in the user's text, limited to the following options:\n"
                "['Absorption', 'Abstract thinking', 'Achievement-striving', 'Aesthetics', 'Affability', 'Aggression', 'Altruism', 'Anger', 'Anxiety', 'Assertive', 'Attention-seeking', 'Callous', 'Courageous', 'Critical', 'Dependability', 'Depression', 'Detail-conscious', 'Dishonest-Opportunism', 'Distractibility', 'Eccentricity', 'Emotion-based decision-making', 'Empathy', 'Envy', 'Extrospection', 'Fair', 'Fantasy', 'Forgiving', 'Grandiosity', 'Gratitude', 'Harm avoidance', 'Hedonism', 'Honesty', 'Humor', 'Imagination', 'Impetuous', 'Indecisive', 'Inferiority', 'Insecure attachment', 'Intellectual curiosity', 'Intolerance', 'Introspection', 'Leadership', 'Manipulative', 'Need for cognition', 'Need for social acceptance', 'Novelty seeking', 'Orderly', 'Perseverance', 'Personal disclosure', 'Planful', 'Positivity', 'Procrastination', 'Provocative', 'Punitive', 'Risk-aversion', 'Rude', 'Rumination', 'Self-control', 'Self-efficacy', 'Self-reliance', 'Sensation seeking', 'Sensitivity', 'Sensitivity to criticism', 'Sociability', 'Social boldness', 'Social confidence', 'Social dependence', 'Spirituality', 'Stubborn', 'Surgency', 'Suspicious', 'Tolerance for ambiguity', 'Traditionalism', 'Vengeful', 'Vigor', 'Warmth', 'Worry']"
            )
        },
        {
            "role": "user",
            "content": content
        }
]
